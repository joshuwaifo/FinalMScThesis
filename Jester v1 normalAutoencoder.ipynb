# %%
from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)

import numpy as np
from keras.layers import Input, Dense
from keras.models import Model
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# helper function loss function
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 
    
embedding_dim = 1 # dimension of embedding

# %%
X_train =  np.load("J1_Xtr.npy")
X_val =  np.load("J1_Xval.npy")
X_test =  np.load("J1_Xtest.npy")

# %% [markdown]
# # binary label

# %%
# load labels
y_train_bin =  np.load("J1_ytrBin.npy")
y_val_bin =  np.load("J1_yvalBin.npy")
y_test_bin =  np.load("J1_ytestBin.npy")

# %%
# normal autoencoder (Selu)

# %%
# joint (multi task learning model) loss

from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)

x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='selu')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='selu')(hidden_enc)
hidden_dec = Dense(2, activation='selu')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='selu')(hidden_dec)
predictor = Dense(1, activation='selu')(hidden_dec)



# Model(input, output): map the input to its reconstruction
# definition of autoencoder
joint_model = Model(inputs=x_input, outputs=[reconstructed_input, predictor])


joint_model.summary()

joint_model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

joint_model.fit(
    x = [X_train], 
    y = [X_train, y_train_bin],
    epochs = 1,
    batch_size = 32,
    validation_data = ([X_val], [X_val, y_val_bin])
)
joint_model.evaluate([X_test], [X_test, y_test_bin])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            6           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            3           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            4           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            6           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            3           dense_3[0][0]
# ==================================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 175s 71us/step - loss: 17099.8014 - dense_4_loss: 17099.3582 - dense_5_loss: 0.4432 - val_loss: 10510.3434 - val_dense_4_loss: 10509.9095 - val_dense_5_loss: 0.4339
# 827272/827272 [==============================] - 23s 28us/step
# [10519.981867341545, 10519.548098127792, 0.43376817636926823]

# %%
# 2 single (consecutive) loss

# separate
from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)



x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='selu')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='selu')(hidden_enc)
hidden_dec = Dense(2, activation='selu')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='selu')(hidden_dec)


# Model(input, output): map the input to its reconstruction
# definition of autoencoder
autoencoder = Model(x_input, reconstructed_input)


# map the input to its embedding (encoded representation)
encoder = Model(x_input, embedding)


autoencoder.summary()

autoencoder.compile(optimizer='rmsprop', loss=root_mean_squared_error)

autoencoder.fit(
    X_train, X_train,
    epochs=3,
    batch_size=32,
    validation_data = (X_val, X_val)
)

# part 2
predictor = Dense(1, activation='selu')(embedding)

model = Model(x_input, predictor)

model.summary()

model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

model.fit(
    X_train, y_train_bin,
    epochs=1,
    batch_size=32,
    validation_data = (X_val, y_val_bin)
)
model.evaluate(X_test, y_test_bin)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 3
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 4
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 6
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/3
# 2481816/2481816 [==============================] - 167s 67us/step - loss: 17068.3990 - val_loss: 10475.2695
# Epoch 2/3
# 2481816/2481816 [==============================] - 164s 66us/step - loss: 5281.8434 - val_loss: 2835.8678
# Epoch 3/3
# 2481816/2481816 [==============================] - 152s 61us/step - loss: 3058.7398 - val_loss: 4679.5130
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 3
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 145s 58us/step - loss: 0.4186 - val_loss: 0.4166
# 827272/827272 [==============================] - 18s 21us/step
# 0.4165297583973134

# %%
# normal autoencoder (sigmoid)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database',)).History will not be written to the database.

# %%
# joint (multi task learning model) loss

from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)

x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='sigmoid')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='sigmoid')(hidden_enc)
hidden_dec = Dense(2, activation='sigmoid')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='sigmoid')(hidden_dec)
predictor = Dense(1, activation='sigmoid')(hidden_dec)



# Model(input, output): map the input to its reconstruction
# definition of autoencoder
joint_model = Model(inputs=x_input, outputs=[reconstructed_input, predictor])


joint_model.summary()

joint_model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

joint_model.fit(
    x = [X_train], 
    y = [X_train, y_train_bin],
    epochs = 5,
    batch_size = 32,
    validation_data = ([X_val], [X_val, y_val_bin])
)
joint_model.evaluate([X_test], [X_test, y_test_bin])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            6           input_3[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            3           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 2)            4           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 2)            6           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            3           dense_13[0][0]
# ==================================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/5
# 2481816/2481816 [==============================] - 305s 123us/step - loss: nan - dense_14_loss: nan - dense_15_loss: nan - val_loss: nan - val_dense_14_loss: nan - val_dense_15_loss: nan
# Epoch 2/5
# 2481816/2481816 [==============================] - 270s 109us/step - loss: nan - dense_14_loss: nan - dense_15_loss: nan - val_loss: nan - val_dense_14_loss: nan - val_dense_15_loss: nan
# Epoch 3/5
# 2481816/2481816 [==============================] - 255s 103us/step - loss: nan - dense_14_loss: nan - dense_15_loss: nan - val_loss: nan - val_dense_14_loss: nan - val_dense_15_loss: nan
# Epoch 4/5
# 2481816/2481816 [==============================] - 266s 107us/step - loss: nan - dense_14_loss: nan - dense_15_loss: nan - val_loss: nan - val_dense_14_loss: nan - val_dense_15_loss: nan
# Epoch 5/5
# 2481816/2481816 [==============================] - 266s 107us/step - loss: nan - dense_14_loss: nan - dense_15_loss: nan - val_loss: nan - val_dense_14_loss: nan - val_dense_15_loss: nan
# 827272/827272 [==============================] - 35s 42us/step
# [nan, nan, nan]

# %%
# 2 single (consecutive) loss

# separate
from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)


x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='sigmoid')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='sigmoid')(hidden_enc)
hidden_dec = Dense(2, activation='sigmoid')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='sigmoid')(hidden_dec)


# Model(input, output): map the input to its reconstruction
# definition of autoencoder
autoencoder = Model(x_input, reconstructed_input)


# map the input to its embedding (encoded representation)
encoder = Model(x_input, embedding)


autoencoder.summary()

autoencoder.compile(optimizer='rmsprop', loss=root_mean_squared_error)

autoencoder.fit(
    X_train, X_train,
    epochs=1,
    batch_size=32,
    validation_data = (X_val, X_val)
)

# part 2
predictor = Dense(1, activation='sigmoid')(embedding)

model = Model(x_input, predictor)

model.summary()

model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

model.fit(
    X_train, y_train_bin,
    epochs=1,
    batch_size=32,
    validation_data = (X_val, y_val_bin)
)
model.evaluate(X_test, y_test_bin)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 6
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 138s 56us/step - loss: 21035.8640 - val_loss: 21008.1292
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 139s 56us/step - loss: nan - val_loss: nan
# 827272/827272 [==============================] - 18s 22us/step
# nan

# %%
# normal autoencoder (linear/identity)

# %%
# joint (multi task learning model) loss

from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)

x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='linear')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='linear')(hidden_enc)
hidden_dec = Dense(2, activation='linear')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='linear')(hidden_dec)
predictor = Dense(1, activation='linear')(hidden_dec)



# Model(input, output): map the input to its reconstruction
# definition of autoencoder
joint_model = Model(inputs=x_input, outputs=[reconstructed_input, predictor])


joint_model.summary()

joint_model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

joint_model.fit(
    x = [X_train], 
    y = [X_train, y_train_bin],
    epochs = 4,
    batch_size = 32,
    validation_data = ([X_val], [X_val, y_val_bin])
)
joint_model.evaluate([X_test], [X_test, y_test_bin])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 2)            6           input_4[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            3           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 2)            4           dense_17[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 2)            6           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            3           dense_18[0][0]
# ==================================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/4
# 2481816/2481816 [==============================] - 158s 64us/step - loss: 267.9716 - dense_19_loss: 224.1478 - dense_20_loss: 43.8238 - val_loss: 80.9432 - val_dense_19_loss: 67.2680 - val_dense_20_loss: 13.6752
# Epoch 2/4
# 2481816/2481816 [==============================] - 153s 62us/step - loss: 61.3074 - dense_19_loss: 50.6946 - dense_20_loss: 10.6129 - val_loss: 65.7523 - val_dense_19_loss: 59.2171 - val_dense_20_loss: 6.5351
# Epoch 3/4
# 2481816/2481816 [==============================] - 150s 60us/step - loss: 58.9772 - dense_19_loss: 49.5177 - dense_20_loss: 9.4595 - val_loss: 54.2841 - val_dense_19_loss: 46.2612 - val_dense_20_loss: 8.0229
# Epoch 4/4
# 2481816/2481816 [==============================] - 170s 69us/step - loss: 58.8804 - dense_19_loss: 49.5090 - dense_20_loss: 9.3714 - val_loss: 53.4904 - val_dense_19_loss: 43.8213 - val_dense_20_loss: 9.6692
# 827272/827272 [==============================] - 20s 25us/step
# [53.51381246601098, 43.837768589142215, 9.676043868614764]

# %%
# 2 single (consecutive) loss

# separate
from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)


x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='linear')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='linear')(hidden_enc)
hidden_dec = Dense(2, activation='linear')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='linear')(hidden_dec)


# Model(input, output): map the input to its reconstruction
# definition of autoencoder
autoencoder = Model(x_input, reconstructed_input)


# map the input to its embedding (encoded representation)
encoder = Model(x_input, embedding)


autoencoder.summary()

autoencoder.compile(optimizer='rmsprop', loss=root_mean_squared_error)

autoencoder.fit(
    X_train, X_train,
    epochs=3,
    batch_size=32,
    validation_data = (X_val, X_val)
)

# part 2
predictor = Dense(1, activation='linear')(embedding)

model = Model(x_input, predictor)

model.summary()

model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

model.fit(
    X_train, y_train_bin,
    epochs=1,
    batch_size=32,
    validation_data = (X_val, y_val_bin)
)
model.evaluate(X_test, y_test_bin)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 6
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/3
# 2481816/2481816 [==============================] -
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_36 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 172s 69us/step - loss: 4.4199 - val_loss: 4.4231
# 827272/827272 [==============================] - 30s 36us/step
# 4.41695345502781

# %%
# normal autoencoder (linear/identity)

# %%
# joint (multi task learning model) loss

from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)

x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='linear')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='linear')(hidden_enc)
hidden_dec = Dense(2, activation='linear')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='linear')(hidden_dec)
predictor = Dense(1, activation='linear')(hidden_dec)



# Model(input, output): map the input to its reconstruction
# definition of autoencoder
joint_model = Model(inputs=x_input, outputs=[reconstructed_input, predictor])


joint_model.summary()

joint_model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

joint_model.fit(
    x = [X_train], 
    y = [X_train, y_train_cat],
    epochs = 3,
    batch_size = 32,
    validation_data = ([X_val], [X_val, y_val_cat])
)


joint_model.evaluate([X_test], [X_test, y_test_cat])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 2)            6           input_9[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1)            3           dense_41[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 2)            4           dense_42[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 2)            6           dense_43[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1)            3           dense_43[0][0]
# ==================================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/3
# 2481816/2481816 [==============================] - 194s 78us/step - loss: 270.0364 - dense_44_loss: 224.4528 - dense_45_loss: 45.5836 - val_loss: 89.6164 - val_dense_44_loss: 66.0314 - val_dense_45_loss: 23.5850
# Epoch 2/3
# 2481816/2481816 [==============================] - 199s 80us/step - loss: 66.5862 - dense_44_loss: 52.0977 - dense_45_loss: 14.4885 - val_loss: 69.3019 - val_dense_44_loss: 59.3438 - val_dense_45_loss: 9.9580
# Epoch 3/3
# 2481816/2481816 [==============================] - 191s 77us/step - loss: 59.6932 - dense_44_loss: 49.4389 - dense_45_loss: 10.2543 - val_loss: 59.8166 - val_dense_44_loss: 46.1099 - val_dense_45_loss: 13.7066
# 827272/827272 [==============================] - 25s 30us/step
# [59.847099553055195, 46.130026773912164, 13.717072781725294]

# %%
# 2 single (consecutive) loss

# separate
from numpy.random import seed
seed(0)
from tensorflow import set_random_seed
set_random_seed(0)


x_dim = X_train.shape[1]
x_input = Input(shape=(x_dim,))


hidden_enc = Dense(2, activation='linear')(x_input)
# embedding is the user-item embedding (encoded representation)
embedding = Dense(embedding_dim, activation='linear')(hidden_enc)
hidden_dec = Dense(2, activation='linear')(embedding)
# reconstructed_input is the (decoded) reconstruction of the input 
# (lossy reconstruction)
reconstructed_input = Dense(x_dim, activation='linear')(hidden_dec)


# Model(input, output): map the input to its reconstruction
# definition of autoencoder
autoencoder = Model(x_input, reconstructed_input)


# map the input to its embedding (encoded representation)
encoder = Model(x_input, embedding)


autoencoder.summary()

autoencoder.compile(optimizer='rmsprop', loss=root_mean_squared_error)

autoencoder.fit(
    X_train, X_train,
    epochs=3,
    batch_size=32,
    validation_data = (X_val, X_val)
)

# part 2
predictor = Dense(1, activation='linear')(embedding)

model = Model(x_input, predictor)

model.summary()

model.compile(optimizer='rmsprop', loss=root_mean_squared_error)

model.fit(
    X_train, y_train_cat,
    epochs=1,
    batch_size=32,
    validation_data = (X_val, y_val_cat)
)
model.evaluate(X_test, y_test_cat)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_46 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_48 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_49 (Dense)             (None, 2)                 6
# =================================================================
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/3
# 2481816/2481816 [==============================] - 169s 68us/step - loss: 114.8664 - val_loss: 76.6630
# Epoch 2/3
# 2481816/2481816 [==============================] - 162s 65us/step - loss: 51.8634 - val_loss: 58.9732
# Epoch 3/3
# 2481816/2481816 [==============================] - 160s 64us/step - loss: 48.7555 - val_loss: 33.2835
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 2)                 0
# _________________________________________________________________
# dense_46 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2481816 samples, validate on 827272 samples
# Epoch 1/1
# 2481816/2481816 [==============================] - 161s 65us/step - loss: 83.7619 - val_loss: 4.3978
# 827272/827272 [==============================] - 23s 27us/step
# 4.391939556006473
